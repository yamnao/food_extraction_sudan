# %%
# ! pip install transformers sentencepiece

# %% [markdown]
# # Code to translate document from arabic to english

# %%
from openpyxl import load_workbook

# %%
from ipywidgets import FloatProgress, VBox
from IPython.display import display

# Create a progress bar
progress_bar = FloatProgress(value=0, min=0, max=100, description='Loading:')

# Styling through layout (instead of .style)
progress_bar.style = {'description_width': 'initial'}  # Update style directly
progress_bar.layout.width = '500px'  # Adjust the width

# Display progress bar
display(progress_bar)

# Update progress
for i in range(101):
    progress_bar.value = i
# Out:
# FloatProgress(value=0.0, description='Loading:', layout=Layout(width='500px'), style=ProgressStyle(description…

# %%
import pandas as pd
from transformers import MarianMTModel, MarianTokenizer

# Load MarianMT model for Arabic-to-English
model_name = 'Helsinki-NLP/opus-mt-ar-en'
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Define a function to translate text
def translate_text(text):
    if pd.isna(text):  # Handle NaN values
        return text
    try:
        inputs = tokenizer(text, return_tensors="pt", padding=True)
        outputs = model.generate(**inputs)
        return tokenizer.decode(outputs[0], skip_special_tokens=True)
    except Exception as e:
        print(f"Error translating {text}: {e}")
        return text
# Out:
# 2025-02-06 18:06:35.149709: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-02-06 18:06:35.321060: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-06 18:06:35.404574: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-06 18:06:35.429155: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# Load the Excel file
file_path = '../../1. Data available/ISHTM_Hadhreen/Oct. Beneficiary Survey/Completed_Survey Oct 2024.xlsx'
data = pd.read_excel(file_path)

from openpyxl import load_workbook

def get_sheetnames_xlsx(filepath):
    wb = load_workbook(filepath, read_only=True, keep_links=False)
    return wb.sheetnames

sheet_name = get_sheetnames_xlsx(file_path)
sheet_name_translate = [translate_text(name) for name in sheet_name]

# %%
## Open the where we want to save the output
path = '../output/translated_beneficiary_survey_oct_2024.xlsx'
book = load_workbook(path)
writer = pd.ExcelWriter(path, engine = 'openpyxl')

# %%
for index, name in enumerate(sheet_name):
    data = pd.read_excel(file_path, sheet_name = name)
    # Translate column names
    data.columns = [translate_text(col) for col in data.columns]
    # Apply translation to the desired columns
    columns_to_translate = data.columns  # Replace with your actual column names
    for col in columns_to_translate:
        data[col] = data[col].apply(translate_text)
    data.to_excel(writer, sheet_name = sheet_name_translate[index])
writer.close()
# Out:
# Error translating 203.0: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# Error translating 97.0: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# Error translating 85.0: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# Error translating 26.0: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# Error translating 411.0: text input must be of type `str` (single example), `List[str]` (batch or single pretokenized example) or `List[List[str]]` (batch of pretokenized examples).
# ...
